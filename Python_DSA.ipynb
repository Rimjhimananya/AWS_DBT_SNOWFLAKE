# %% [markdown]
# <a href="https://colab.research.google.com/github/Rimjhimananya/AWS_DBT_SNOWFLAKE/blob/main/Python_DSA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
